# %%
x = 10 
y = 25 

print(x+y)
print(x-y)
print(x*y)
print(x/y)

result = (x**2 + y) * ( y - 1 )/ x - y + y**2
print(result)
# Out:
# 35
# -15
# 250
# 0.4
# 900.0

# %%
x = 5 
y = 5 

if x<y:
    print("X меньше Y")  
elif x>y:
    print("X больше Y")
else:
    print("X равен Y")
# Out:
# X равен Y

# %%
for num in range(2,12,2):
    if num>5:
        print(num)
    elif num<5:
        print(-num)
# Out:
# -2
# -4
# 6
# 8
# 10

# %%
n = int(input())
fact = 1 
for NF in range(2,n+1):
    fact=fact*NF 
print(fact)
# Out:
#  9
# 362880
